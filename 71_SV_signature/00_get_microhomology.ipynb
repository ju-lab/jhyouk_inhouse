# %%
#microhomology from bal. INV, TRA, DM, SST, chromothripsis and >=3 rearrangements without deletions

input_list = ['INVTRAecDNA_extraction.txt','chromoplexy3rearrangement_extraction.txt','sst_extraction.txt']

output_file = file("microhomology_all_sv.txt","w")
for input_fn in input_list:
    input_file = file(input_fn)
    input_line = input_file.readline().strip()
    
    while input_line:
        input_split = input_line.split('\t')
        try:
            input_mh = int(input_split[5])
        except:
            'blank'
            #print input_fn
            #print input_line
        #if input_mh == -7:
        #    print input_line
        output_file.write(str(input_mh)+'\n')
        
        input_line = input_file.readline().strip()
        
    input_file.close()
output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#microhomology from control SVs
input_list = ['control_all_SV.txt']

output_file = file("microhomology_control_sv.txt","w")
for input_fn in input_list:
    input_file = file(input_fn)
    input_line = input_file.readline().strip()
    
    while input_line:
        input_split = input_line.split('\t')
        try:
            input_mh = int(input_split[5])
        except:
            print input_fn
            print input_line
            
        output_file.write(str(input_mh)+'\n')
        
        input_line = input_file.readline().strip()
        
    input_file.close()
output_file.close()
print 'THE END'
# Out:
# control_all_SV.txt
# S1N2P15_0-4	13	63501148	17	34897383	.	3to3	TRA	.	.	simpleF_1	.	denovo_subclonal	.	.	.	add
# control_all_SV.txt
# S1N2P15_0-5	4	41194315	.	.	.	5to.	.	.	.	retrotransposition_1	.	denovo_subclonal	.	.	.	add
# control_all_SV.txt
# B3-0_P19_0Gy-1	X	16307953	X	90122666	.	5to5	INV	.	.	directreturn_1	.	denovo_subclonal	.	.	.	add
# control_all_SV.txt
# Liver_C3SO1	1	63294360	18	45024212	.	5to3	TRA	.	NA	retrotransposition_1	0.33	denovo_clonal	30;70;15;5;2;33.33%;17.65%	0;0;59;65	.	modify
# control_all_SV.txt
# Liver_C3SO1	1	63294373	.	.	.	3to.	TRA	.	NA	retrotransposition_1	.	denovo_clonal	.	.	.	add
# control_all_SV.txt
# mm_study4_liver_sham_SO1	2	161177779	.	.	.	3to.	.	T1	NA	balanced_1	0.24	denovo_clonal	26;37;8;4;3;23.53%;17.78%	0;0;43;31	.	.
# control_all_SV.txt
# mm_study4_liver_sham_SO1	2	161177770	.	.	.	5to.	.	.	.	balanced_1	.	denovo_clonal	.	.	.	add
# control_all_SV.txt
# ...

# %%
#gap from INVTRAecDNA_extraction_sort.txt

input_file = file("INVTRAecDNA_extraction_sort.txt")
output_file = file("INVTRAecDNA_extraction_breakpoint.txt","w")
output_file.write("bp1_3\tbp1_5\tbp2_3\tbp2_5\n")
input_line = input_file.readline().strip()
while input_line:
    input_split = input_line.split('\t')
    input_dir1 = input_split[6].split('to')[0]
    input_dir2 = input_split[6].split('to')[1]
    two_break = [0,0,0,0]
       
    if input_dir1 == '3':
        two_break[0] = input_split[2]
    elif input_dir1 == '5':
        two_break[1] = input_split[2]
    else:
        print "direction1"
        print input_line
        
    if input_dir2 == '3':
        two_break[2] = input_split[4]
    elif input_dir2 == '5':
        two_break[3] = input_split[4]
    else:
        print "direction2"
        print input_line
    #print two_break
    input_line = input_file.readline().strip()
    
    input_split = input_line.split('\t')
    input_dir1 = input_split[6].split('to')[0]
    input_dir2 = input_split[6].split('to')[1]
    #two_break = [0,0,0,0]
       
    if input_dir1 == '3':
        two_break[0] = input_split[2]
    elif input_dir1 == '5':
        two_break[1] = input_split[2]
    else:
        print "direction1"
        print input_line
        
    if input_dir2 == '3':
        two_break[2] = input_split[4]
    elif input_dir2 == '5':
        two_break[3] = input_split[4]
    else:
        print "direction2"
        print input_line    
  
    if (int(two_break[3]) - int(two_break[2])) < -5000000:
        print input_line
        
    output_file.write('\t'.join(two_break) + '\n')
    
    input_line = input_file.readline().strip()
output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#gap & mh from INVTRAecDNA_extraction_sort.txt

input_file = file("INVTRAecDNA_extraction_sort.txt")
output_file = file("INVTRAecDNA_extraction_breakpoint_mh_noNA.txt","w")
output_file.write("bp1_3\tbp1_5\tbp2_3\tbp2_5\tmh1_3\tmh1_5\tmh2_3\tmh2_5\n")
input_line = input_file.readline().strip()
while input_line:
    input_split = input_line.split('\t')
    input_dir1 = input_split[6].split('to')[0]
    input_dir2 = input_split[6].split('to')[1]
    two_break = [0,0,0,0,99,99,99,99]
    
    input_mh = input_split[5]
    if input_mh == '.':
        input_line = input_file.readline().strip()
        continue

    if input_dir1 == '3':
        two_break[0] = input_split[2]
        two_break[4] = input_mh
    elif input_dir1 == '5':
        two_break[1] = input_split[2]
        two_break[5] = input_mh
    else:
        print "direction1"
        print input_line
        
    if input_dir2 == '3':
        two_break[2] = input_split[4]
        two_break[6] = input_mh
    elif input_dir2 == '5':
        two_break[3] = input_split[4]
        two_break[7] = input_mh
    else:
        print "direction2"
        print input_line
    
    input_line = input_file.readline().strip()
    
    input_split = input_line.split('\t')
    input_dir1 = input_split[6].split('to')[0]
    input_dir2 = input_split[6].split('to')[1]

    
    input_mh = input_split[5]
    if input_mh == '.':
        input_line = input_file.readline().strip()
        continue
        
    if input_dir1 == '3':
        two_break[0] = input_split[2]
        two_break[4] = input_mh
    elif input_dir1 == '5':
        two_break[1] = input_split[2]
        two_break[5] = input_mh
    else:
        print "direction1"
        print input_line
        
    if input_dir2 == '3':
        two_break[2] = input_split[4]
        two_break[6] = input_mh
    elif input_dir2 == '5':
        two_break[3] = input_split[4]
        two_break[7] = input_mh
    else:
        print "direction2"
        print input_line    
            
    output_file.write('\t'.join(two_break) + '\n')
    
    input_line = input_file.readline().strip()
    
output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#gap & mh from SSDI cohort

input_file = file("SSDI_selection_from_my_sample_same_strategy.txt")
output_file = file("SSDI_selection_breakpoint_mh.txt","w")
output_file.write("del1_3\tdel1_5\tdel2_3\tdel2_5\tins_3\tins_5\tmh1_3\tmh1_5\tmh2_3\tmh2_5\tmh3_3\tmh3_5\n")
input_line = input_file.readline().strip()
while input_line:
    input_split = input_line.split('\t')
    two_break = [0,0,0,0,0,0,99,99,99,99,99,99]    
    
    del_chr = input_split[1]

    two_break[0] = input_split[2]
    two_break[3] = input_split[4]
    two_break[6] = input_split[5]
    two_break[9] = input_split[5]
    
    input_line = input_file.readline().strip()
    
    input_split = input_line.split('\t')
    input_type = input_split[7]
    input_dir = input_split[6]

    
    if input_type == 'TRA':
        if input_split[1] == del_chr:
            if input_dir.split('to')[0] == '3':
                two_break[2] = input_split[2]
                two_break[8] = input_split[5]
            else:
                two_break[1] = input_split[2]
                two_break[7] = input_split[5]
                
            if input_dir.split('to')[1] == '3':
                two_break[4] = input_split[4]
                two_break[10] = input_split[5]
            else:
                two_break[5] = input_split[4]  
                two_break[11] = input_split[5]
        else:
            if input_dir.split('to')[1] == '3':
                two_break[2] = input_split[4]
                two_break[8] = input_split[5]
            else:
                two_break[1] = input_split[4]
                two_break[7] = input_split[5]
                
            if input_dir.split('to')[0] == '3':
                two_break[4] = input_split[2]
                two_break[10] = input_split[5]
            else:
                two_break[5] = input_split[2]
                two_break[11] = input_split[5]
                
                
        input_line = input_file.readline().strip()
        input_split = input_line.split('\t')
        input_type = input_split[7]
        input_dir = input_split[6]        
        if input_split[1] == del_chr:
            if input_dir.split('to')[0] == '3':
                two_break[2] = input_split[2]
                two_break[8] = input_split[5]
            else:
                two_break[1] = input_split[2]
                two_break[7] = input_split[5]
                
            if input_dir.split('to')[1] == '3':
                two_break[4] = input_split[4]
                two_break[10] = input_split[5]
            else:
                two_break[5] = input_split[4]  
                two_break[11] = input_split[5]
        else:
            if input_dir.split('to')[1] == '3':
                two_break[2] = input_split[4]
                two_break[8] = input_split[5]
            else:
                two_break[1] = input_split[4]
                two_break[7] = input_split[5]
                
            if input_dir.split('to')[0] == '3':
                two_break[4] = input_split[2]
                two_break[10] = input_split[5]
            else:
                two_break[5] = input_split[2]
                two_break[11] = input_split[5]
                
    elif input_type == 'INV':
        if input_dir == '5to5': # insertion site is larger than deletion site in all cases
            two_break[1] = input_split[2]
            two_break[5] = input_split[4]
            two_break[7] = input_split[5]
            two_break[11] = input_split[5]
        else:
            two_break[2] = input_split[2]
            two_break[4] = input_split[4]
            two_break[8] = input_split[5]
            two_break[10] = input_split[5]            

        input_line = input_file.readline().strip()
        input_split = input_line.split('\t')
        input_type = input_split[7]
        input_dir = input_split[6]          
        if input_dir == '5to5': # insertion site is larger than deletion site in all cases
            two_break[1] = input_split[2]
            two_break[5] = input_split[4]
            two_break[7] = input_split[5]
            two_break[11] = input_split[5]
        else:
            two_break[2] = input_split[2]
            two_break[4] = input_split[4]
            two_break[8] = input_split[5]
            two_break[10] = input_split[5]
    else: # DEL-DUP-DEL cases
        if input_dir == '5to3': # insertion site is larger than deletion site in all cases
            two_break[1] = input_split[2]
            two_break[4] = input_split[4]
            two_break[7] = input_split[5]
            two_break[10] = input_split[5]
        elif input_dir == '3to5':
            two_break[2] = input_split[2]
            two_break[5] = input_split[4]
            two_break[8] = input_split[5]
            two_break[11] = input_split[5]   
            
        input_line = input_file.readline().strip()
        input_split = input_line.split('\t')
        input_type = input_split[7]
        input_dir = input_split[6]              
        if input_dir == '5to3': # insertion site is larger than deletion site in all cases
            two_break[1] = input_split[2]
            two_break[4] = input_split[4]
            two_break[7] = input_split[5]
            two_break[10] = input_split[5]
        elif input_dir == '3to5':
            two_break[2] = input_split[2]
            two_break[5] = input_split[4]
            two_break[8] = input_split[5]
            two_break[11] = input_split[5]       

    output_file.write('\t'.join(two_break) + '\n')
    
    input_line = input_file.readline().strip()
    
output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#gap & mh from chromoplexy & >=3rearrangements

input_file = file("chromoplexy3rearrangement_extraction.txt")

input_line = input_file.readline().strip()
while input_line:
    input_split = input_line.split('\t')
    input_dir1 = input_split[6].split('to')[0]
    input_dir2 = input_split[6].split('to')[1]
    input_mh = input_split[5]
    
    print [input_split[1],input_split[2],'dir=' + input_dir1,input_mh]
    print [input_split[3],input_split[4],'dir=' + input_dir2,input_mh]
    
    
    input_line = input_file.readline().strip()
# Out:
# ['12', '38090237', 'dir=3', '1']
# ['18', '14014408', 'dir=5', '1']
# ['12', '38090238', 'dir=5', '1']
# ['17', '21428954', 'dir=3', '1']
# ['17', '21428965', 'dir=5', '1']
# ['18', '14014399', 'dir=3', '1']
# ['X', '19458769', 'dir=3', '0']
# ['X', '52061908', 'dir=5', '0']
# ['X', '19458797', 'dir=5', '1']
# ['X', '89177501', 'dir=3', '1']
# ['X', '52061901', 'dir=3', '2']
# ['X', '56212631', 'dir=3', '2']
# ['X', '56212646', 'dir=5', '2']
# ['X', '89177301', 'dir=5', '2']
# ['3', '40933822', 'dir=3', '1']
# ['9', '38817452', 'dir=3', '1']
# ['3', '40933831', 'dir=5', '0']
# ['3', '41091199', 'dir=5', '0']
# ['3', '41091200', 'dir=3', '0']
# ['9', '38816576', 'dir=5', '0']
# ['9', '38816562', 'dir=3', '-3']
# ['9', '38817457', 'dir=5', '-3']
# ['6', '33987498', 'dir=3', '1']
# ['7', '113375913', 'dir=3', '1']
# ['6', '33987511', 'dir=5', '0']
# ['7', '94164654', 'dir=3', '0']
# ['7', '94164656', 'dir=5', '2']
# ['7', '113375918', 'dir=5', '2']
# ['4', '38265044', 'dir=3', '1']
# ...

# %%
#SST mh selection
input_file = file("SSDI_selection_from_my_sample_same_strategy.txt")
output_file = file("SSDI_mh_only.txt","w")

input_line = input_file.readline().strip()
while input_line:
    output_file.write(input_line.split('\t')[5]+'\n')
    input_line = input_file.readline().strip()
    
output_file.close()
print 'THE END'
# Out:
# THE END

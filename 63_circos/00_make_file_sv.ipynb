# %%
#to make SV input file for mm10 circos

input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
#input_fn = "S1N2P16_4-8.delly.somatic.annotated.filter1.motherinfo.filter2.reviewed.vcf"
for input_fn in input_id:
    try:
        input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/33_SV_filter/" + input_fn + '.delly.somatic.annotated.filter1.motherinfo.filter2.reviewed.vcf')
    except:
        try:
            input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/33_SV_filter/" + input_fn + '.delly.somatic.annotated.filter1.reviewed.vcf')
        except:
            input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/33_SV_annotation/' + input_fn + '.delly.somatic.annotated.filter1.reviewed.vcf')
   
    #input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/33_SV_filter/" + input_fn)
    output_file = file(input_fn.split('.delly')[0].replace("_retry","") + '_SV.input', 'w')

    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()

    while input_line:
        input_split = input_line.split('\t')

        input_type = input_split[6]
        input_direction = input_split[5]
        input_color = '.'

        if input_type == 'DEL':
            input_color = 'blue'
        elif input_type == 'DUP':
            input_color = 'green'
        elif input_type == 'INV':
            if input_direction == '3to3':
                input_color = 'red'
            elif input_direction == '5to5':
                input_color = 'orange'
            else:
                print input_fn
                print "no defined direction in INV cases"
                print input_line
                input_line = input_file.readline().strip()
                continue
        elif input_type == 'TRA':
            input_color = 'purple'
        elif input_type == 'INS':
            input_color = 'grey'
        else:
            print input_fn
            print input_line
            input_line = input_file.readline().strip()
            continue
        input_decision = input_split[9].split('_')[0]
        input_thickness = 5
        if input_decision == 'chromoplexy':
            input_thickness = 15

        input_chr1 = 'mm' + input_split[0]
        input_pos1 = int(input_split[1])
        input_chr2 = 'mm' + input_split[2]
        input_pos2 = int(input_split[3])

        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))

        input_line = input_file.readline().strip()

    output_file.close()
    
#output_file1.close()
print 'THE END'
# Out:
# S1N2P16_4-8
# 15	29468000	.	.	.	5to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P16_4-8
# 15	7201907	.	.	.	3to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P15_2-6
# X	83035704	.	.	.	3to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P15_2-6
# X	113181487	.	.	.	3to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P15_2-6
# X	156687195	.	.	.	5to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P15_2-6
# X	169469826	.	.	.	3to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# S1N2P15_2-6
# X	162702038	.	.	.	5to.	.	.	.	chromothripsis_1	.	denovo_clonal	.	.	.	add
# mm_study4_fallopian_IR_SO2
# 4	3249168	.	.	.	5to.	.	.	.	BFB_1	.	denovo_clonal	.	.	.	add
# mm_study4_fallopian_IR_SO2
# 13	56106651	.	.	.	5to.	.	.	.	SSDI_1	.	denovo_clonal	.	.	.	add
# mm_study4_fallopian_IR_SO2
# 13	56107453	.	.	.	3to.	.	.	.	SSDI_1	.	denovo_clonal	.	.	.	add
# mm_study4_fallopian_IR_SO2
# 15	6965773	.	.	.	5to.	.	.	.	BFB_1	.	denovo_clonal	.	.	.	add
# ...

# %%
# make CNV input file for hg19 circos

#input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
input_id = ["mm_study4_fallopian_IR_SO2"]
for input_fn in input_id:
    input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/07_sequenza/" + input_fn.replace("_retry","") + ".mpileup.100kbcov.absCN" )
    output_file = file(input_fn.replace(".mpileup.100kbcov.absCN","") + '_CNV.input','w')

    input_line = input_file.readline().strip()

    while input_line:
        if input_line[0:1] == '#':
            input_line = input_file.readline().strip()
            continue
        input_split = input_line.split('\t')
        input_chr = 'mm' + input_split[0]
        input_pos = int(input_split[1])
        try:
            input_CN = float(input_split[4])
        except:
            input_line = input_file.readline().strip()
            continue
        
        if input_CN >20:
            input_CN = 20

        output_file.write("%s\t%s\t%s\t%s\n" %(input_chr, input_pos, input_pos + 100000 -1, input_CN))
        input_line = input_file.readline().strip()
    output_file.close()
    
print 'THE END'
# Out:
# THE END

# %%
# make SV input file for hg19 circos

# input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","HBIR2-1","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
input_id = ["HBIR2-1"]

for input_fn in input_id:
    input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/33_SV_annotation/' + input_fn + '.delly.somatic.annotated.filter1.reviewed.vcf')

    output_file = file(input_fn.split('.delly')[0].replace("_retry","") + '_SV.input', 'w')

    input_line = input_file.readline().strip()
    input_line = input_file.readline().strip()

    while input_line:
        input_split = input_line.split('\t')

        input_type = input_split[6]
        input_direction = input_split[5]
        input_color = '.'

        if input_type == 'DEL':
            input_color = 'blue'
        elif input_type == 'DUP':
            input_color = 'green'
        elif input_type == 'INV':
            if input_direction == '3to3':
                input_color = 'red'
            elif input_direction == '5to5':
                input_color = 'orange'
            else:
                print input_fn
                print "no defined direction in INV cases"
                print input_line
                input_line = input_file.readline().strip()
                continue
        elif input_type == 'TRA':
            input_color = 'purple'
        elif input_type == 'INS':
            input_color = 'grey'
        else:
            print input_fn
            print input_line
            input_line = input_file.readline().strip()
            continue
        input_decision = input_split[9].split('_')[0]
        input_thickness = 5
        if input_decision == 'chromoplexy':
            input_thickness = 15

        input_chr1 = 'hs' + input_split[0]
        input_pos1 = int(input_split[1])
        input_chr2 = 'hs' + input_split[2]
        input_pos2 = int(input_split[3])

        output_file.write("%s\t%s\t%s\t%s\t%s\t%s\tcolor=%s,thickness=%sp\n" %(input_chr1,input_pos1,input_pos1,input_chr2,input_pos2,input_pos2,input_color,input_thickness))

        input_line = input_file.readline().strip()

    output_file.close()
    
#output_file1.close()
print 'THE END'
# Out:
# HBIR2-1
# X	57021392	.	.	.	5to.	.	.	.	balanced_1	.	denovo_clonal	.	.	.	add
# THE END

# %%
input_id = ["HBIR2-1"]

for input_fn in input_id:
    input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/07_sequenza/" + input_fn.replace("_retry","") + ".mpileup.100kbcov.absCN" )
    output_file = file(input_fn.replace(".mpileup.100kbcov.absCN","") + '_CNV.input','w')

    input_line = input_file.readline().strip()

    while input_line:
        if input_line[0:1] == '#':
            input_line = input_file.readline().strip()
            continue
        input_split = input_line.split('\t')
        input_chr = 'hs' + input_split[0]
        input_pos = int(input_split[1])
        try:
            input_CN = float(input_split[4])
        except:
            input_line = input_file.readline().strip()
            continue
        
        if input_CN >10:
            input_CN = 10

        output_file.write("%s\t%s\t%s\t%s\n" %(input_chr, input_pos, input_pos + 100000 -1, input_CN))
        input_line = input_file.readline().strip()
    output_file.close()
    
print 'THE END'
# Out:
# THE END

# %%
input_id = ["Liver_20Gy1_SO2_retry","S1N2P16_4-7","mm_study2_pancreas_8by1Gy_SO2_retry","HBIR2-1","S1N2P16_4-8","S1N2P15_2-6","mm_study4_fallopian_IR_SO2"]
input_file = file("exercise.conf")
output_file1 = file("00_run_circos.sh","w")

for i in input_id:
    output_file1.write("circos -conf %s.conf\n" % i.replace("_retry",""))
    output_file = file(i.replace("_retry","") + ".conf",'w')
    input_file.seek(0)
    input_line = input_file.readline().strip()
    input_species = 'mouse.mm10'
    if i == 'HBIR2-1':
        input_species = 'human'
        
    while input_line:
        if input_line[0:9] == 'karyotype' and input_species == 'human':
            temp_line = input_line.replace("mouse.mm10",input_species)
        elif input_line[0:4] == 'file':
            temp_line = input_line.replace("S1N2P16_4-8",i.replace("_retry",""))
        else: 
            temp_line = input_line
            
        output_file.write(temp_line + '\n')
        
        
        input_line = input_file.readline().strip()
        
    output_file.close()
output_file1.close()
print 'THE END'
# Out:
# THE END

# %%
#SNP_TRUE_rearrange
info_file = file('00_9_mouse_human_190813.txt')

info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_id = []

while info_line:
    info_id.append(info_line.split('\t')[0].replace("_retry",""))
    info_line = info_file.readline().strip()

#print len(info_id)

n5=0
n6=0
n6c=0
nh=0

for i in info_id:
    try:
        input_file = file('/home/users/jhyouk/05_mm10_SNUH_radiation_partial/31_snp_annotation/' + i + '_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.coverage.vcf')
    except:
        try:
            input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/31_2_SNP_updated_190315/' + i + '_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.coverage.vcf')
        except:
            try:
                input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/31_2_SNP_updated_190315/' + i + '_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.readc.rasmy.filter2.vcf')
            except:
                input_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/' + i + '_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.coverage.vcf')
    
    output_file = file('/home/users/jhyouk/06_mm10_SNUH_radiation/31_2_SNP_updated_190315/gene_annotation/' + i + 'snp_True.vcf','w')
    
    input_line = input_file.readline()
    output_file.write("#CHROM\tPOS\tID\tREF\tALT\tQUAL\tVat\n")
    
    input_line = input_file.readline()
    while input_line:
        input_split = input_line.split('\t')
        if input_split[34] == 'T':
            output_file.write('\t'.join(input_split[0:7])+'\t'+input_split[33]+'\n')
        input_line = input_file.readline()
    output_file.close()
print 'THE END'
# Out:
# THE END

# %%
#call for nonsyn snp in cancer gene census of mm10

from collections import Counter
from operator import itemgetter

def numeric_compare(x, y):
    return int(x) - int(y)

info_file = file("/home/users/jhyouk/99_reference/mouse/mm10/mouse_cancer_gene_census_biomart.txt")
list_file = file('00_9_mouse_human_190813.txt')

list_line = list_file.readline().strip()
list_line = list_file.readline().strip()
list_id=[]
while list_line:
    list_id.append(list_line.split('\t')[0].replace("_retry",""))
    list_line = list_file.readline().strip()
    
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_gene = []
while info_line:
    info_gene.append(info_line.split('\t')[0])
    info_line=info_file.readline().strip()
n=0
m=0
census_list=[]
ID_list=[]

#interesting_list = ['Notch1','Cdkn1b', 'Alk', 'Sf3b1', 'Tet2', 'Bap1', 'Jak3', 'Brca2', 'Atrx', 'Setd1b', 'Flt3', 'Keap1', 'Trp53', 'Rara', 'Kif5b', 'Ercc5', 'Arid1a', 'Blm', 'Cdkn2c', 'Palb2', 'Pdgfb', 'Axin1', 'Eml4', 'Apc', 'Mtor', 'Ezh2', 'Ercc2']
repeat_list = ['Trp53']
for i in list_id:
    try:
        input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/31_2_SNP_updated_190315/gene_annotation/"+i+"snp_True.vcf.anv")
    except:
        input_line = input_file.readline()
        continue
    n+=1
    input_line = input_file.readline()
    input_line = input_file.readline()
    while input_line:
        input_split = input_line.split('\t')
        if (input_split[8] == 'exonic' or input_split[8] == 'splicing') and input_split[11] != 'synonymous SNV' and float(input_split[7])>=0.3:
            if input_split[9] in info_gene:
                #if input_split[9] in census_list:
                    #'blank'
                #else:
                census_list.append(input_split[9])                    
                if input_split[9] in repeat_list:
                    print i, input_line
                    
                if i in ID_list:
                    'blank'
                else:
                    ID_list.append(i)
                    #if i == 'S1N2P16_4-8' or i== 'S1N2P15_2-6' or i== 'mm_study4_fallopian_IR_SO2':
                        #print i,input_line
                m+=1
                
        input_line = input_file.readline()

result = Counter(census_list)
final_list = []
for key in result:
    final_list.append([key, result[key]])
final_sort = sorted(final_list,key=itemgetter(1),cmp=numeric_compare,reverse=True)
print 'THE END'
#print census_list
#print ID_list
for i in final_sort:
    print i
# Out:
# THE END
# ['Rnf213', 43]
# ['Lpp', 42]
# ['Zfp874a', 20]
# ['Zeb1', 11]
# ['Grm3', 10]
# ['Bcl9', 2]
# ['Fat4', 2]
# ['Ssxb3', 1]
# ['Ccr7', 1]
# ['Specc1', 1]
# ['Was', 1]
# ['Nkx2-1', 1]
# ['Trim33', 1]
# ['Hif1a', 1]
# ['Tdpoz3', 1]
# ['Bap1', 1]
# ['Epas1', 1]
# ['Thrap3', 1]
# ['Cdkn1b', 1]
# ['Map3k1', 1]
# ['Lrp1b', 1]
# ['Setd1b', 1]
# ['Col1a1', 1]
# ['Ackr3', 1]
# ['Picalm', 1]
# ['Dcaf12l2', 1]
# ['Birc6', 1]
# ['Jak3', 1]
# ['Ep300', 1]

# %%
#call for nonsyn snp in cancer gene census of hg19

from collections import Counter
from operator import itemgetter

def numeric_compare(x, y):
    return int(x) - int(y)

info_file = file("/home/users/jhyouk/99_reference/mouse/mm10/mouse_cancer_gene_census_biomart.txt")
list_file = file('00_9_mouse_human_190813.txt')

list_line = list_file.readline().strip()
list_line = list_file.readline().strip()
list_id=[]
while list_line:
    list_id.append(list_line.split('\t')[0].replace("_retry",""))
    list_line = list_file.readline().strip()
    
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_gene = []
while info_line:
    info_gene.append(info_line.split('\t')[1])
    info_line=info_file.readline().strip()
n=0
m=0
census_list=[]
ID_list=[]

#interesting_list = ['Notch1','Cdkn1b', 'Alk', 'Sf3b1', 'Tet2', 'Bap1', 'Jak3', 'Brca2', 'Atrx', 'Setd1b', 'Flt3', 'Keap1', 'Trp53', 'Rara', 'Kif5b', 'Ercc5', 'Arid1a', 'Blm', 'Cdkn2c', 'Palb2', 'Pdgfb', 'Axin1', 'Eml4', 'Apc', 'Mtor', 'Ezh2', 'Ercc2']
repeat_list = []
for i in list_id:
    try:
        input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/31_2_SNP_updated_190315/gene_annotation/human_snp/"+i+"snp_True.vcf.anv")
    except:
        input_line = input_file.readline()
        continue
    n+=1
    input_line = input_file.readline()
    input_line = input_file.readline()
    while input_line:
        input_split = input_line.split('\t')
        if (input_split[8] == 'exonic' or input_split[8] == 'splicing') and input_split[11] != 'synonymous SNV' and float(input_split[7])>=0.3:
            if input_split[9] in info_gene:
                #if input_split[9] in census_list:
                    #'blank'
                #else:
                census_list.append(input_split[9])                    
                if input_split[9] in repeat_list:
                    print i, input_line
                    
                if i in ID_list:
                    'blank'
                else:
                    ID_list.append(i)
                    #if i == 'S1N2P16_4-8' or i== 'S1N2P15_2-6' or i== 'mm_study4_fallopian_IR_SO2':
                        #print i,input_line
                m+=1
                
        input_line = input_file.readline()

result = Counter(census_list)
final_list = []
for key in result:
    final_list.append([key, result[key]])
final_sort = sorted(final_list,key=itemgetter(1),cmp=numeric_compare,reverse=True)
print 'THE END'
#print census_list
#print ID_list
for i in final_sort:
    print i
# Out:
# THE END
# ['KMT2D', 2]
# ['MUC4', 2]
# ['MUC16', 2]
# ['ROBO2', 2]
# ['MYH11', 1]
# ['FUBP1', 1]
# ['KMT2A', 1]
# ['TNFRSF14', 1]
# ['SMARCA4', 1]
# ['QKI', 1]
# ['NCOA1', 1]
# ['TFEB', 1]
# ['NTRK1', 1]
# ['CBFB', 1]
# ['JAK3', 1]
# ['MALT1', 1]
# ['CDKN2C', 1]
# ['PDGFB', 1]
# ['NCKIPSD', 1]
# ['CREB1', 1]
# ['TRRAP', 1]
# ['BRD3', 1]
# ['FAT3', 1]
# ['FLNA', 1]
# ['EWSR1', 1]

# %%
#Mouse
info_file = file("/home/users/jhyouk/99_reference/mouse/mm10/mouse_cancer_gene_census_biomart.txt")
   
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_gene = []
while info_line:
    info_gene.append(info_line.split('\t')[0])
    info_line=info_file.readline().strip()
    
n=0
m=0
print info_gene
print len(info_gene)
interest_gene = ["Dgkb","Zfp54","Mrpl48","Nol4","Zfp398","Agbl4","Kcbq4"]

for i in interest_gene:
    print i
    if i in info_gene:
        print 'Success'
# Out:
# ['Klf6', 'Tfe3', 'Axin2', 'Sdhd', 'Ccnd2', 'Cdh1', 'Tmprss2', 'Lck', 'Pparg', 'Raf1', 'Pdgfb', 'Ddx3x', 'Usp32', 'Bcl11a', 'Smarcb1', 'Araf', 'Snd1', 'Nkx2-1', 'Col1a1', 'Mnx1', 'Hoxc13', 'Hoxc11', 'Akt1', 'Smo', 'Crnkl1', 'Hoxd13', 'Rac1', 'Nup214', 'Kmt2a', 'Ccne1', 'Ddb2', 'Stat6', 'Daxx', 'Braf', 'Tsc2', 'Cdkn1b', 'Klf4', 'Elf3', 'Stk11', 'Cdk12', 'Pafah1b2', 'Bcl2l12', 'Sh3gl1', 'Ranbp2', 'Plag1', 'Keap1', 'Cd79a', 'Crtc1', 'Calr', 'Bax', 'Il7r', 'Hlf', 'Grm3', 'Stat3', 'Akt2', 'Etv1', 'Ptpn6', 'Cul3', 'Pax3', 'Prcc', 'Map2k1', 'Hnrnpa2b1', 'Ndrg1', 'Fgfr4', 'Msh6', 'Fbxo11', 'Cic', 'Prkaca', 'Dnajb1', 'Kit', 'Ctcf', 'Apc', 'Ncoa2', 'Tpr', 'Tfpt', 'Cbfa2t3', 'Mpl', 'Runx1t1', 'Cdk4', 'Kif5b', 'Ctnnb1', 'Pole', 'Ppp2r1a', 'Fance', 'Rhoa', 'Id3', 'Arid1a', 'Nfib', 'Nf2', 'Ewsr1', 'Met', 'Myod1', 'Bcr', 'Sdhb', 'Kdsr', 'Cars', 'Phox2b', 'Etv5', 'Pten', 'Pax5', 'Cox6c', 'Camta1', 'Gata2', 'Arnt', 'Gata3', 'Setdb1', 'Nfe2l2', 'Cacna1d', 'Fli1', 'H2-M3', 'H2-M2', 'Wt1', 'Ppfibp1', 'Cd
# ...

# %%
#Human
info_file = file("/home/users/jhyouk/99_reference/mouse/mm10/mouse_cancer_gene_census_biomart.txt")
   
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_gene = []
while info_line:
    info_gene.append(info_line.split('\t')[1])
    info_line=info_file.readline().strip()
    
n=0
m=0

interest_gene = ["UBQLN1"]

for i in interest_gene:
    print i
    if i in info_gene:
        print 'Success'
# Out:
# UBQLN1

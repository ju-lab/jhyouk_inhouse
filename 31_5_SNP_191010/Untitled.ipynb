# %%
# select true call only
import os
#start
temp_list = os.listdir("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation")
file_list = []
for ll in temp_list:
    if 'T_snp' in ll or 're_snp' in ll or 'mem_snp' in ll or 'new_snp' in ll:
        if 'filter1.vcf' in ll:
            file_list.append(ll)

#file_list.append("")
print len(file_list)

for input_fn in file_list:
    print input_fn
    input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/" + input_fn)
    output_file = file("human/" + input_fn.split('_union')[0] + ".true.vcf" , "w")
    input_line = input_file.readline().strip()
    output_file.write(input_line +'\n')
    input_line = input_file.readline().strip()
    
    while input_line:
        input_split = input_line.split('\t')
        if input_split[34] == 'T':
            output_file.write(input_line + '\n')
        input_line = input_file.readline().strip()
    output_file.close()
print 'THE END'
# Out:
# 16
# 18-2419T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# 19-1621T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S12_10269_T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S17_11918T_re_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# 15-1494T_mem_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# 15-1034-T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S17_11918T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S15_40859_T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S14_54949_T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# 15-495-T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S17_50179_T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# S160041844_T_new_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# 18_1360T_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf
# ...

# %%
# snp & indel number
import os, subprocess

temp_list = os.listdir("/home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/mouse")
file_list = []
input_ID = []
for ll in temp_list:
    if '.true.vcf' in ll:
        file_list.append(ll)
        input_ID.append(ll.split('/')[-1].split('.true')[0])
#print input_ID
print len(file_list)

temp_list2 = os.listdir("/home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/mouse")
file_list2 = []
for ll in temp_list2:
    if '.true.clonal.vcf' in ll:
        file_list2.append(ll)
print len(file_list2)

temp_list3 = os.listdir("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse")
file_list3 = []
for ll in temp_list3:
    if '.true.vcf' in ll:
        file_list3.append(ll)
print len(file_list3)
temp_list4 = os.listdir("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse")
file_list4 = []
for ll in temp_list4:
    if '.true.clonal.vcf' in ll:
        file_list4.append(ll)
print len(file_list4)


num_snp = []
num_clonal_snp = []
num_indel = []
num_clonal_indel = []

for i in range(0,len(file_list)):
    #input_ID = []
    num_snp.append("")
    num_clonal_snp.append("")
    num_indel.append("")
    num_clonal_indel.append("")
#print num_snp
#output_file = file("snp_indel_number.txt",'w')
#output_file.write("#ID\tSNPt\clonalSNP\tINDEL\tclonalINDEL\n")
#print input_ID
for input_fn in file_list:
    p = subprocess.Popen("wc -l /home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/mouse/%s" % input_fn , stdout=subprocess.PIPE, shell=True)
    (output, err) = p.communicate()
    num_snp[input_ID.index(input_fn.split('/')[-1].split('.true')[0])] = output.split(' ')[0]
    
for input_fn in file_list2:
    p = subprocess.Popen("wc -l /home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/mouse/%s" % input_fn , stdout=subprocess.PIPE, shell=True)
    (output, err) = p.communicate()
    num_clonal_snp[input_ID.index(input_fn.split('/')[-1].split('.true')[0])] = output.split(' ')[0]
#print num_snp
#print num_clonal_snp
for input_fn in file_list3:
    p = subprocess.Popen("wc -l /home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse/%s" % input_fn , stdout=subprocess.PIPE, shell=True)
    (output, err) = p.communicate()
    num_indel[input_ID.index(input_fn.split('/')[-1].split('.true')[0].replace("_2nd",""))] = output.split(' ')[0]
for input_fn in file_list4:
    p = subprocess.Popen("wc -l /home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse/%s" % input_fn , stdout=subprocess.PIPE, shell=True)
    (output, err) = p.communicate()
    num_clonal_indel[input_ID.index(input_fn.split('/')[-1].split('.true')[0].replace("_2nd",""))] = output.split(' ')[0]

output_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse/mouse_organoid_snp_indel_number.txt",'w')
output_file.write("#ID\tSNP\tclonalSNP\tINDEL\tclonalINDEL\n")
n=0
while n < len(input_ID):
    output_file.write("%s\t%s\t%s\t%s\t%s\n" %(input_ID[n],num_snp[n],num_clonal_snp[n],num_indel[n],num_clonal_indel[n]))    
    n+=1
output_file.close()
print 'THE END'
# Out:
# 141
# 67
# 141
# 67
# THE END

# %%
import subprocess
p = subprocess.Popen("wc -l /home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/human/hs_study5_colon_IR_HCIR1_SC1.true.vcf", stdout=subprocess.PIPE, shell=True)
#p = subprocess.Popen("date", stdout=subprocess.PIPE, shell=True)
(output, err) = p.communicate()
print output


print err
# Out:
# 3724 /home/users/jhyouk/06_mm10_SNUH_radiation/31_5_SNP_191010/human/hs_study5_colon_IR_HCIR1_SC1.true.vcf
#
# None

# %%
info_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/S1P12_0-7_indel_union_2.readinfo.readc.rasmy.pon.filter1.readc.rasmy.filter2.vcf")
info_line = info_file.readline().strip()
info_line = info_file.readline().strip()
info_list = []
while info_line:
    info_split = info_line.split('\t')
    temp = [info_split[0],info_split[1]]
    info_list.append(temp)
    info_line = info_file.readline().strip()
#print len(info_list)

input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/mouse/N1-S1.true.clonal.vcf")
input_line = input_file.readline().strip()
input_line = input_file.readline().strip()
n=0
class1='none_to_clonal'
class2='none_to_subclonal'
class3='subclonal_to_clonal'
class4='subclonal_to_subclonal'
class5='subclonal_to_none'
class6='clonal_to_none'
class7='clonal_to_subclonal'
class8='clonal_to_clonal'

while input_line:
    input_split = input_line.split('\t')
    temp = [input_split[0],input_split[1]]
    if temp not in info_list:
        n+=1
        print input_split[0],input_split[1],input_split[30]
    #else:
        #print input_split[30]
    input_line = input_file.readline().strip()
print n
# Out:
# 1 5762739 99;4;1;1;1.01
# 1 48624089 NA;NA;0;0;0
# 1 180198705 NA;NA;0;0;0
# 2 34076100 131;4;1;1;0.76
# 2 139010169 NA;NA;0;0;0
# 2 170644429 118;4;1;1;0.85
# 3 76569271 NA;NA;0;0;0
# 3 106664612 NA;NA;0;0;0
# 3 113989419 138;4;1;1;0.72
# 3 141094690 NA;NA;0;0;0
# 4 10575084 NA;NA;0;0;0
# 4 12541212 NA;NA;0;0;0
# 4 15113489 NA;NA;0;0;0
# 4 15627409 128;4;1;1;0.78
# 4 26578513 141;4;1;1;0.71
# 4 27799012 NA;NA;0;0;0
# 4 28075471 120;4;2;2;1.67
# 4 31363007 NA;NA;0;0;0
# 4 31525211 NA;NA;0;0;0
# 4 35101650 NA;NA;0;0;0
# 4 38488378 NA;NA;0;0;0
# 4 45909986 NA;NA;0;0;0
# 4 47743137 NA;NA;0;0;0
# 4 49959497 NA;NA;0;0;0
# 4 50136012 NA;NA;0;0;0
# 4 56553268 NA;NA;0;0;0
# 4 59221076 181;4;2;1;1.1
# 4 63657547 172;4;1;1;0.58
# 4 69103827 150;4;1;1;0.67
# 4 75563022 NA;NA;0;0;0
# 4 85440246 NA;NA;0;0;0
# 4 92960013 NA;NA;0;0;0
# 4 95419274 NA;NA;0;0;0
# 4 100528977 NA;NA;0;0;0
# 4 111121007 NA;NA;0;0;0
# 4 113304007 NA;NA;0;0;0
# 4 113585278 153;4;1;1;0.65
# 4 114948823 151;4;1;1;0.66
# ...

# %%
input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/human/human_tumor/19-1546T.true.vcf")
input_line = input_file.readline().strip()
input_line = input_file.readline().strip()
n=0
strict_n=0

output_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/32_5_INDEL_191010/human/human_tumor/19-1546T.read.txt","w")
output_file.write("CHROM\tPOS\tread_ref\tread_var\tPON_ref\tPON_var\n")
while input_line:
    input_split = input_line.split('\t')
    output_file.write("%s\t%s\t%s\t%s\t%s\t%s\n" %(input_split[0],input_split[1],input_split[29].split(';')[9],input_split[29].split(';')[10],input_split[30].split(';')[0],input_split[30].split(';')[2]))
    #print input_split[0],input_split[1],input_split[32],input_split[33]
    n+=1
    if float(input_split[32]) == 0:
        strict_n+=1
        #print input_split[30]
    input_line = input_file.readline().strip()
print n
print strict_n
output_file.close()
# Out:
# 4431
# 3038

# %%
input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/snuh_bam_list.txt")
input_line = input_file.readline().strip()
ID_list = []
while input_line:
    input_split = input_line.split('\t')
    ID_list.append(input_split[0].replace(".s.md.ir.br.bam",""))
    input_line = input_file.readline().strip()
print ID_list

for input_fn in ID_list:
    print input_fn
    input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/" + input_fn + "_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf")
    input_line = input_file.readline().strip()
    output_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/" + input_fn + "_snp_true_forSig.vcf","w")
    input_split = input_line.split('\t')
    output_file.write('\t'.join(input_split[0:10])+'\n')
    input_line = input_file.readline().strip()
    while input_line:
        input_split = input_line.split('\t')
        if input_split[34] == 'T':
            output_file.write('\t'.join(input_split[0:10])+'\n')
        input_line = input_file.readline().strip()
    output_file.close()
    input_file.close()
print 'THE END'
# Out:
# ['15-495-T', '15-1494T_mem', '15-1034-T', '18_1360T', '19-1621T', '18-2419T', '18_1277T', 'S160041844_T_new', '19-1546T', 'S14_54949_T', 'S15_40859_T', 'S17_11918T', 'S17_50179_T', 'S15_40859_17_T_new', 'S17_11918T_re', 'S12_10269_T']
# 15-495-T
# 15-1494T_mem
# 15-1034-T
# 18_1360T
# 19-1621T
# 18-2419T
# 18_1277T
# S160041844_T_new
# 19-1546T
# S14_54949_T
# S15_40859_T
# S17_11918T
# S17_50179_T
# S15_40859_17_T_new
# S17_11918T_re
# S12_10269_T
# THE END

# %%
ID_list = ['S17_11918T','S17_11918T_re']
for input_fn in ID_list:
    print input_fn
    input_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/" + input_fn + "_snp_union_2.readinfo.readc.rasmy_PanelofNormal.filter1.vcf")
    input_line = input_file.readline().strip()
    output_file = file("/home/users/jhyouk/06_mm10_SNUH_radiation/GRCh37/31_SNP_annotation/" + input_fn + "_snp_true_forSig.vcf","w")
    input_split = input_line.split('\t')
    output_file.write('\t'.join(input_split[0:10])+'\n')
    input_line = input_file.readline().strip()
    while input_line:
        input_split = input_line.split('\t')
        if input_split[34] == 'T':
            input_split[8] = '.'
            input_split[9] = '.'
            output_file.write('\t'.join(input_split[0:10])+'\n')
        input_line = input_file.readline().strip()
    output_file.close()
    input_file.close()
print 'THE END'
# Out:
# S17_11918T
# S17_11918T_re
# THE END
